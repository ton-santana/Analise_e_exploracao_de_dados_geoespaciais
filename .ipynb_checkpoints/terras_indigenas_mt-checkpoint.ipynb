# %% [markdown]
# # Localizando Terras Indígenas no Estado do Mato Grosso.

# %% [markdown]
# Este jupyter notebook tem como objetivo somente colocar em prática alguns dos conhecimentos em análise exploratória de dados geográficos que adquiri nos últimos tempos.

# %% [markdown]
# * Importando bibliotecas

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Incluindo Shapefile com os estados do Brasil.
# * Fonte: <a href="https://geoservicos.ibge.gov.br/geoserver/ows?version=1.3.0">Geoserver IBGE</a>, camada: CGEO:UF_2013

# %%
# Lendo GeoDataFrame estados.
estados = gpd.read_file("estados/estados.shp")

# %%
# Verificando tipo do arquivo criado.
type(estados)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %% [markdown]
# * Para realizar operações com arquivos shapefiles diferentes utilizando GeoPandas é necessário que os arquivos estejam no mesmo sistema de projeção geográfica, caso contrário, é necessário fazer a conversão.

# %%
# Verificando o sistema de coordenadas do arquivo
print(estados.crs)
# Out:
# epsg:4674

# %% [markdown]
# Como podemos verificar, o EPSG do arquivo é 4674, Sirgas 2000

# %%
# Apresentando as cinco primeiras linhas do DataFrame.
estados.head()
# Out:
#      uf   nome_uf sigla_uf grandreg  \
# 0  11.0  Rondônia       RO    Norte
# 1  12.0      Acre       AC    Norte
# 2  13.0  Amazonas       AM    Norte
# 3  14.0   Roraima       RR    Norte
# 4  15.0      Pará       PA    Norte
#
#                                             geometry
# 0  POLYGON ((-63.38701 -7.97659, -63.11838 -7.977...
# 1  POLYGON ((-73.18253 -7.33550, -73.12014 -7.358...
# 2  POLYGON ((-67.32609 2.02971, -67.31682 2.00125...
# 3  POLYGON ((-60.17884 5.23017, -60.17245 5.22656...
# 4  MULTIPOLYGON (((-46.06095 -1.09470, -46.06666 ...

# %% [markdown]
# A coluna geometry é a coluna onde ficam as coordenadas do shapefile, no GeoDataFrame de estados elas podem ser do tipo Polygon ou Multipolygon. Quando uma terra indígena é formada por um ou mais polígonos, ela é do tipo Multipolígono.

# %% [markdown]
# * Selecionando o estado do Mato Grosso.

# %%
# Filtrando estados pela sigla.
mt = estados[estados["sigla_uf"] == 'MT']

# %%
# Apresentando a linha contendo o resultado da seleção.
mt
# Out:
#       uf      nome_uf sigla_uf      grandreg  \
# 22  51.0  Mato Grosso       MT  Centro-Oeste
#
#                                              geometry
# 22  POLYGON ((-57.93439 -7.65677, -57.93044 -7.657...

# %% [markdown]
# * Plotando o mapa do estado do Mato Grosso.

# %%
mt.plot(figsize=(15,8))
plt.title("Estado do Mato Grosso")
# Out:
# Text(0.5, 1.0, 'Estado do Mato Grosso')

# %% [markdown]
# ## Incluindo o GeoDataFrame com as Terras Indígenas.

# %% [markdown]
# * Fonte: <a href="http://geoserver.funai.gov.br">Geoserver Funai</a>, camada: ti_sirgas

# %%
# Carregando DataFrame.
terras_indigenas = gpd.read_file("ti_sirgas/ti_sirgas.shp")

# %%
# Verificando o sistema de projeção do arquivo.
print(terras_indigenas.crs)
# Out:
# epsg:4674

# %% [markdown]
# Podemos ver que o arquivo de terras indígenas também está no EPSG 4674, Sirgas 2000.

# %%
# Apresentando as cinco primeiras linhas do DataFrame de terras indígenas.
terras_indigenas.head()
# Out:
#    gid  terrai_cod        terrai_nom   etnia_nome municipio_ uf_sigla  \
# 0    1         101   Acapuri de Cima       Kokama  Fonte Boa       AM
# 1    2         201             Acimã      Apurinã     Lábrea       AM
# 2   57         601             Aconã  Tingui-Botó     Traipu       AL
# 3   62         401  Água Preta/Inari      Apurinã     Pauini       AM
# 4    3         501       Águas Belas       Pataxó      Prado       BA
#
#     superficie       fase_ti                modalidade reestudo_t  \
# 0   18393.9411     Declarada  Tradicionalmente ocupada       None
# 1   40686.0340  Regularizada  Tradicionalmente ocupada       None
# 2     267.7862  Regularizada          Reserva Indígena       None
# 3  139763.6705  Regularizada  Tradicionalmente ocupada       None
# 4    1189.0649  Regularizada  Tradicionalmente ocupada       None
#
#                                       cr faixa_fron    undadm_cod  \
# 0  COORDENACAO REGIONAL DO ALTO SOLIMOES        Não  3.020200e+10
# 1       COORDENACAO REGIONAL MÉDIO PURUS        Não  3.020200e+10
# 2        COORDENACAO REGIONAL NORDESTE I        Não  3.020200e+10
# 3       COORDENACAO REGIONAL MÉDIO PURUS        Não  3.020200e+10
# 4      COORDENACAO REGIONAL SUL DA BAHIA        Não  3.020200e+10
#
#                               undadm_nom undadm_sig dominio_un  \
# 0  COORDENACAO REGIONAL DO ALTO SOLIMOES      CR-AS          f
# 1       COORDENACAO REGIONAL MÉDIO PURUS    CR-Mpur          t
# 2        COORDENACAO REGIONAL NORDESTE I    CR-NE-I          t
# 3       COORDENACAO REGIONAL MÉDIO PURUS    CR-Mpur          t
# 4      COORDENACAO REGIONAL SUL DA BAHIA     CR-SBA          t
#
#                                             geometry
# 0  POLYGON ((-66.88359 -2.53752, -66.87457 -2.537...
# 1  POLYGON ((-66.30929 -7.79995, -66.30929 -7.799...
# 2  POLYGON ((-36.94514 -10.07113, -36.94377 -10.0...
# 3  POLYGON ((-67.29764 -7.33958, -67.29713 -7.338...
# 4  POLYGON ((-39.30549 -16.90608, -39.30501 -16.9...

# %% [markdown]
# * Filtrando as terras indigenas presentes no estado do Mato Grosso, algumas terras indígenas estão entre o Mato Grosso e o Amazonas, Pará e Rondônia.

# %%
# Aplicando seleção.
ti_mt = terras_indigenas.loc[(terras_indigenas["uf_sigla"] == "MT") | (terras_indigenas["uf_sigla"] == "MT,PA") 
                             | (terras_indigenas["uf_sigla"] == "PA,MT") |  (terras_indigenas["uf_sigla"] == "MT,RO") 
                             | (terras_indigenas["uf_sigla"] == "RO,MT")]

# %%
# Exibindo o resultado da seleção de terras indígenas no estado do Mato Grosso.
ti_mt.head()
# Out:
#     gid  terrai_cod                   terrai_nom       etnia_nome  \
# 24    8       68301  Apiaká do Pontal e Isolados  Isolados,Apiaká
# 25    7        2301                Apiaka/Kayabi    Apiaká,Kaiabi
# 39   29        3301          Arara do Rio Branco    Arara do Acre
# 44   69        3901                       Areões          Xavante
# 45   70        4201                     Aripuanã      Cinta Larga
#
#           municipio_ uf_sigla   superficie       fase_ti  \
# 24           Apiacás       MT  982324.0000    Delimitada
# 25             Juara       MT  109245.3822  Regularizada
# 39  Aripuanã,Colniza       MT  114842.4748  Regularizada
# 44          Água Boa       MT  218515.0000  Regularizada
# 45    Aripuanã,Juína       MT  750649.2650  Regularizada
#
#                   modalidade reestudo_t  \
# 24  Tradicionalmente ocupada       None
# 25  Tradicionalmente ocupada       None
# 39  Tradicionalmente ocupada       None
# 44  Tradicionalmente ocupada       None
# 45  Tradicionalmente ocupada       None
#
#                                               cr faixa_fron    undadm_cod  \
# 24     COORDENACAO REGIONAL NORTE DO MATO GROSSO        Não  3.020200e+10
# 25  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO        Não  3.020200e+10
# 39  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO        Não  3.020200e+10
# 44     COORDENACAO REGIONAL RIBEIRAO CASCALHEIRA        Não  3.020200e+10
# 45  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO        Não  3.020200e+10
#
#                                       undadm_nom undadm_sig dominio_un  \
# 24     COORDENACAO REGIONAL NORTE DO MATO GROSSO     CR-NMT          f
# 25  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO    CR-NOMT          t
# 39  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO    CR-NOMT          t
# 44     COORDENACAO REGIONAL RIBEIRAO CASCALHEIRA      CR-RC          t
# 45  COORDENACAO REGIONAL NOROESTE DO MATO GROSSO    CR-NOMT          t
#
#                                              geometry
# 24  POLYGON ((-58.32480 -7.97798, -58.32524 -7.973...
# 25  POLYGON ((-57.23662 -10.81354, -57.23542 -10.8...
# 39  POLYGON ((-59.39807 -9.77770, -59.39954 -9.778...
# 44  POLYGON ((-51.89056 -14.15934, -51.89049 -14.1...
# 45  POLYGON ((-60.12701 -10.10921, -60.12660 -10.1...

# %% [markdown]
# * Plotando mapa com as terras indígenas no estado do Mato Grosso.

# %%
# Exibindo mapa das terras indígenas.
ti_mt.plot(figsize=(15,8))
plt.title("Terras Indígenas")
# Out:
# Text(0.5, 1.0, 'Terras Indígenas')

# %% [markdown]
# * Exibindo o mapa do estado do Matro Grosso contendo as suas respectivas terras indígenas.

# %%
# Plotando o mapa do estado do Mato Grosso e as terras indígenas juntos.
fig, ax = plt.subplots(figsize = (15,15))
mt.plot(ax = ax, color = "lightgrey")
ti_mt.plot(ax = ax)
plt.title("Terras Indígenas no Estado do Matro Grosso")
# Out:
# Text(0.5, 1.0, 'Terras Indígenas no Estado do Matro Grosso')

# %% [markdown]
# ## Próximos passos

# %% [markdown]
# Como próximos passos, pode-se verificar a quantidade de área do estado que é pertencente a terras indígenas, melhorar a apresentação do mapa e exportar o mapa em formato PDF.
